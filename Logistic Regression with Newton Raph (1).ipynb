# %% [markdown]
# ## Logistic regression using Newton-raphson method

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\pavan\anaconda3\lib\site-packages (0.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importing needed libraries

# %%
from ucimlrepo import fetch_ucirepo
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### importing breast cancer diagnostic dataset

# %%
cancer_data = fetch_ucirepo(id=17)

# %%
features = cancer_data.data.features
targets = cancer_data.data.targets

# %% [markdown]
# ### data preprocessing

# %%
# Map labels 'M' (Malignant) to 1 and 'B' (Benign) to 0
label_mapping = {'M': 1, 'B': 0}
targets['Diagnosis'] = targets['Diagnosis'].map(label_mapping)
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_11660\2224132023.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   targets['Diagnosis'] = targets['Diagnosis'].map(label_mapping)

# %% [markdown]
# ### Set test and validation split sizes
# testing    - 80% data of training data
# validation - 80% data of testing data

# %%
split_data_size = 0.2

# %%
# Split the data into training, validation, and test sets
train_features, temp_features, train_targets, temp_targets = train_test_split(
    features, targets, test_size=split_data_size, random_state=np.random.randint(1, 100))
val_features, test_features, val_targets, test_targets = train_test_split(
    temp_features, temp_targets, test_size=split_data_size, random_state=np.random.randint(1, 100))

# %% [markdown]
# #### defining necessory functions for calculating gradient

# %%
# sigmoid function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# calculate probabilities
def calculate_probabilities(features, coefficients):
    return np.array(sigmoid(features.dot(coefficients[:, 0])), ndmin=2).T

# calculate the weight matrix
def calculate_weight_matrix(probabilities):
    return np.diag((probabilities * (1 - probabilities))[:, 0])

# calculate the Hessian matrix
def calculate_hessian(features, weight_matrix):
    return features.T.dot(weight_matrix).dot(features)

# calculate the gradient
def calculate_gradient(features, targets, probabilities):
    return features.T.dot(targets - probabilities)

# %%
# Newton-Raphson method
def newton_raphson_step(curr_coefficients, targets, features, regularization=None):
    probabilities = calculate_probabilities(features, curr_coefficients)
    weight_matrix = calculate_weight_matrix(probabilities)

    features = features.reset_index(drop=True)
    targets.reset_index(drop=True, inplace=True)

    hessian = calculate_hessian(features, weight_matrix)
    gradient = calculate_gradient(features, targets, probabilities)

    print("-------------")
    # Regularization step
    if regularization:
        step = np.dot(np.linalg.inv(hessian + regularization * np.eye(curr_coefficients.shape[0])), gradient)
    else:
        step = np.dot(np.linalg.inv(hessian), gradient)

    new_coefficients = curr_coefficients + step
    return new_coefficients

# %%
# check for convergence
def has_converged(coefficients_old, coefficients_new, tolerance, iterations):
    coefficient_change = np.abs(coefficients_old - coefficients_new)
    print(coefficient_change)
    return not (np.any(coefficient_change > tolerance) and iterations < max_iterations)

# %%
# evaluate the model accuracy
def evaluate_model(features, targets, coefficients):
    probabilities = calculate_probabilities(features, coefficients)

    predictions = np.greater(probabilities, 0.5 * np.ones((probabilities.shape[1], 1)))
    accuracy = np.count_nonzero(np.equal(predictions, targets)) / probabilities.shape[0] * 100
    return accuracy

# %%
# Maximum no of iter
max_iterations = 20  

# Convergence
tolerance = 0.1  

# Regularization
regularization_term = 1

# %%
# coefficients
coefficients_old, coefficients = np.ones((30, 1)), np.zeros((30, 1))
iteration_count = 0
coefficients_converged = False

# %%
# Main loop
while not coefficients_converged:
    print('Validation Accuracy after iteration {}: {}%'.format(iteration_count + 1, evaluate_model(val_features, val_targets, coefficients_old)))
    coefficients_old = coefficients
    coefficients = newton_raphson_step(coefficients, train_targets, train_features, regularization_term)
    iteration_count += 1
    coefficients_converged = has_converged(coefficients_old, coefficients, tolerance, iteration_count)
# Out:
# Validation Accuracy after iteration 1: 39.56043956043956%
# -------------
# [[2.20041051]
#  [0.00883832]
#  [0.05418487]
#  [0.01606687]
#  [0.01103325]
#  [0.15081524]
#  [0.41004335]
#  [0.46876387]
#  [0.11080624]
#  [0.20780549]
#  [0.72554204]
#  [0.05812243]
#  [0.09192721]
#  [0.01514838]
#  [0.00945185]
#  [0.08170142]
#  [0.27383756]
#  [0.06702955]
#  [0.01624766]
#  [0.02181531]
#  [1.24176359]
#  [0.0395791 ]
#  [0.00455729]
#  [0.00671306]
#  [0.03523705]
#  [0.58052401]
#  [0.90475272]
#  [0.89066198]
#  [0.09421879]
#  [0.1698731 ]]
# Validation Accuracy after iteration 2: 60.43956043956044%
# -------------
# [[1.37991900e+00]
#  [1.43061426e-02]
#  [5.20998504e-02]
#  [1.08948782e-02]
#  [8.51021653e-02]
#  [1.50024630e-01]
#  [2.78784324e-01]
#  [3.19458487e-01]
#  [1.49143484e-02]
#  [9.33440895e-02]
#  [6.16739444e-01]
#  [2.36990097e-01]
#  [1.61795895e-01]
#  [1.45721941e-02]
#  [1.58538245e-02]
#  [6.17352003e-02]
#  [2.14860380e-01]
#  [3.91525970e-02]
#  [7.59889148e-04]
#  [1.67070508e-02]
#  [5.77188079e-01]
#  [5.55428408e-02]
#  [2.77648947e-03]
#  [3.37813714e-03]
#  [1.44321022e-01]
#  [4.04592636e-01]
#  [3.30971064e-01]
#  [5.66338393e-01]
#  [2.10918596e-01]
#  [7.59983682e-02]]
# Validation Accuracy after iteration 3: 94.5054945054945%
# -------------
# [[1.06195487]
#  [0.03596393]
#  [0.06395186]
#  [0.00816207]
#  [0.1060329 ]
#  [0.12432028]
#  [0.22084169]
#  [0.23037505]
#  [0.05503586]
#  [0.04393605]
#  [0.35419275]
#  [0.48825324]
#  [0.06539332]
#  [0.01986444]
#  [0.01178364]
#  [0.07750028]
#  [0.1746438 ]
#  [0.02089264]
#  [0.00401506]
#  [0.01461251]
#  [0.19639745]
#  [0.09230541]
#  [0.00440655]
#  [0.00219163]
#  [0.16750689]
#  [0.29949064]
#  [0.29361272]
#  [0.41316714]
#  [0.25833079]
#  [0.0259455 ]]
# Validation Accuracy after iteration 4: 96.7032967032967%
# -------------
# [[0.66276393]
#  [0.04114921]
#  [0.10626373]
#  [0.00167029]
#  [0.08078786]
#  [0.07168652]
#  [0.09725175]
#  [0.14548122]
#  [0.03886054]
#  [0.02042713]
#  [0.07834343]
#  [0.46978392]
#  [0.37244051]
#  [0.06535422]
#  [0.00619104]
#  [0.09409239]
#  [0.17541977]
#  [0.00900037]
#  [0.01318562]
#  [0.01539113]
#  [0.39076464]
#  [0.08663966]
#  [0.01479231]
#  [0.00382788]
#  [0.14159852]
#  [0.20446302]
#  [0.2065541 ]
#  [0.29445007]
#  [0.22391172]
#  [0.00548931]]
# Validation Accuracy after iteration 5: 96.7032967032967%
# -------------
# [[0.55170246]
#  [0.02577543]
#  [0.07838652]
#  [0.00435355]
#  [0.06144506]
#  [0.06007002]
#  [0.07055738]
#  [0.12302171]
#  [0.0540565 ]
#  [0.01198432]
#  [0.0177456 ]
#  [0.35458969]
#  [0.40334606]
#  [0.07310879]
#  [0.00570113]
#  [0.07822954]
#  [0.148042  ]
#  [0.00968875]
#  [0.00645855]
#  [0.01324993]
#  [0.4379612 ]
#  [0.06755487]
#  [0.02798979]
#  [0.00646559]
#  [0.12654185]
#  [0.15414709]
#  [0.1832079 ]
#  [0.25315292]
#  [0.22594193]
#  [0.00070444]]
# Validation Accuracy after iteration 6: 95.6043956043956%
# -------------
# [[0.58921884]
#  [0.00117743]
#  [0.08957185]
#  [0.00617184]
#  [0.05918911]
#  [0.07312614]
#  [0.10526158]
#  [0.12930202]
#  [0.06875219]
#  [0.00765597]
#  [0.02995638]
#  [0.20229877]
#  [0.33261763]
#  [0.05097948]
#  [0.00804813]
#  [0.0614166 ]
#  [0.11300141]
#  [0.01298704]
#  [0.0018909 ]
#  [0.01059516]
#  [0.41410344]
#  [0.04980408]
#  [0.01721674]
#  [0.00857326]
#  [0.12202735]
#  [0.11192861]
#  [0.18975289]
#  [0.24157573]
#  [0.22931326]
#  [0.00087029]]
# Validation Accuracy after iteration 7: 95.6043956043956%
# -------------
# [[0.52500533]
#  [0.00056167]
#  [0.08440204]
#  [0.00394204]
#  [0.05772501]
#  [0.06771616]
#  [0.10334705]
#  [0.12639503]
#  [0.06965536]
#  [0.00657306]
#  [0.01987199]
#  [0.14227927]
#  [0.24843846]
#  [0.03454365]
#  [0.00818136]
#  [0.06029209]
#  [0.10554965]
#  [0.0127253 ]
#  [0.00250328]
#  [0.01023313]
#  [0.29626034]
#  [0.03724867]
#  [0.00838815]
#  [0.00569806]
#  [0.11903198]
#  [0.07384353]
#  [0.16376635]
#  [0.22788639]
#  [0.225007  ]
#  [0.00293755]]
# Validation Accuracy after iteration 8: 95.6043956043956%
# -------------
# [[0.41933961]
#  [0.00223036]
#  [0.0642336 ]
#  [0.00109166]
#  [0.05533862]
#  [0.05265429]
#  [0.08203004]
#  [0.1178249 ]
#  [0.06671791]
#  [0.00703905]
#  [0.01085782]
#  [0.09729824]
#  [0.20221339]
#  [0.02293882]
#  [0.00788415]
#  [0.06318433]
#  [0.10921814]
#  [0.01130253]
#  [0.0013119 ]
#  [0.01052262]
#  [0.1441028 ]
#  [0.02135612]
#  [0.00708283]
#  [0.00187771]
#  [0.11463754]
#  [0.02890765]
#  [0.10613409]
#  [0.20925739]
#  [0.2129434 ]
#  [0.0064142 ]]
# Validation Accuracy after iteration 9: 95.6043956043956%
# -------------
# [[3.38709752e-01]
#  [2.10322557e-03]
#  [4.37668203e-02]
#  [2.88851622e-04]
#  [5.31629777e-02]
#  [4.02099221e-02]
#  [6.34464720e-02]
#  [1.10424537e-01]
#  [6.34929830e-02]
#  [7.68401494e-03]
#  [5.48347344e-03]
#  [6.27557949e-02]
#  [1.62505379e-01]
#  [1.64831763e-02]
#  [7.61988230e-03]
#  [6.55251628e-02]
#  [1.13339599e-01]
#  [1.01194295e-02]
#  [2.99952599e-05]
#  [1.08051246e-02]
#  [4.27489917e-02]
#  [1.20937318e-02]
#  [6.76458847e-03]
#  [1.43521253e-04]
#  [1.10605788e-01]
#  [4.89417885e-03]
#  [6.01818769e-02]
#  [1.94394571e-01]
#  [2.00502025e-01]
#  [9.24140125e-03]]
# Validation Accuracy after iteration 10: 95.6043956043956%
# -------------
# [[0.28658511]
#  [0.00065024]
#  [0.0299382 ]
#  [0.000843  ]
#  [0.05143791]
#  [0.03188166]
#  [0.05089964]
#  [0.10514123]
#  [0.06064864]
#  [0.00817664]
#  [0.0026068 ]
#  [0.03786819]
#  [0.12676202]
#  [0.01234771]
#  [0.00743116]
#  [0.06679616]
#  [0.11585979]
#  [0.00932598]
#  [0.00099046]
#  [0.01097939]
#  [0.01267689]
#  [0.00713235]
#  [0.00603101]
#  [0.00047159]
#  [0.107426  ]
#  [0.02664793]
#  [0.03144715]
#  [0.18406531]
#  [0.18974348]
#  [0.01111797]]
# Validation Accuracy after iteration 11: 95.6043956043956%
# -------------
# [[0.25124858]
#  [0.00061405]
#  [0.0218911 ]
#  [0.00106213]
#  [0.05003514]
#  [0.02609694]
#  [0.04222172]
#  [0.10121726]
#  [0.05810443]
#  [0.00855201]
#  [0.00114677]
#  [0.02087937]
#  [0.09730832]
#  [0.00928991]
#  [0.00728567]
#  [0.06743512]
#  [0.11730683]
#  [0.00877369]
#  [0.00183154]
#  [0.01108641]
#  [0.04243273]
#  [0.00406147]
#  [0.00495386]
#  [0.00070763]
#  [0.1048947 ]
#  [0.04079402]
#  [0.01380163]
#  [0.17668302]
#  [0.18046974]
#  [0.01235759]]
# Validation Accuracy after iteration 12: 95.6043956043956%
# -------------
# [[0.22553241]
#  [0.00148368]
#  [0.01714298]
#  [0.00112951]
#  [0.04885199]
#  [0.02179341]
#  [0.03587427]
#  [0.09812263]
#  [0.05578334]
#  [0.00885249]
#  [0.0004925 ]
#  [0.00972887]
#  [0.07422641]
#  [0.00701425]
#  [0.00716491]
#  [0.06772558]
#  [0.11811031]
#  [0.00836598]
#  [0.00255753]
#  [0.0111546 ]
#  [0.05823874]
#  [0.00210748]
#  [0.00386099]
#  [0.00078597]
#  [0.10282564]
#  [0.05029015]
#  [0.00292906]
#  [0.17115703]
#  [0.17236813]
#  [0.01319266]]
# Validation Accuracy after iteration 13: 95.6043956043956%
# -------------
# [[0.20564687]
#  [0.00203568]
#  [0.01418767]
#  [0.00112644]
#  [0.04782269]
#  [0.01840134]
#  [0.03101295]
#  [0.09556248]
#  [0.05364183]
#  [0.00910127]
#  [0.00029878]
#  [0.00261632]
#  [0.05658889]
#  [0.00533555]
#  [0.00705952]
#  [0.06781242]
#  [0.11849765]
#  [0.00805112]
#  [0.00320185]
#  [0.01119773]
#  [0.06622719]
#  [0.00086362]
#  [0.00291237]
#  [0.00079347]
#  [0.10108601]
#  [0.0568377 ]
#  [0.00366251]
#  [0.16684594]
#  [0.16519763]
#  [0.01376099]]
# Validation Accuracy after iteration 14: 95.6043956043956%
# -------------
# [[1.89523389e-01]
#  [2.36327639e-03]
#  [1.22333602e-02]
#  [1.09153042e-03]
#  [4.69050017e-02]
#  [1.56089123e-02]
#  [2.71584595e-02]
#  [9.33686440e-02]
#  [5.16526795e-02]
#  [9.31138904e-03]
#  [3.66677955e-04]
#  [1.81272638e-03]
#  [4.32871886e-02]
#  [4.10246676e-03]
#  [6.96445232e-03]
#  [6.77720863e-02]
#  [1.18596425e-01]
#  [7.79998032e-03]
#  [3.78304177e-03]
#  [1.12228884e-02]
#  [6.96968649e-02]
#  [7.37585133e-05]
#  [2.14787149e-03]
#  [7.69796756e-04]
#  [9.95835539e-02]
#  [6.14425586e-02]
#  [7.45723766e-03]
#  [1.63361905e-01]
#  [1.58777199e-01]
#  [1.41466973e-02]]
# Validation Accuracy after iteration 15: 95.6043956043956%
# -------------
# [[0.17597635]
#  [0.00254044]
#  [0.01086083]
#  [0.00104329]
#  [0.04607106]
#  [0.0132363 ]
#  [0.02402   ]
#  [0.09144001]
#  [0.04979606]
#  [0.00949107]
#  [0.00057978]
#  [0.00450323]
#  [0.03332099]
#  [0.00319716]
#  [0.00687682]
#  [0.0676481 ]
#  [0.11848732]
#  [0.00759479]
#  [0.00431267]
#  [0.01123428]
#  [0.07049177]
#  [0.00042557]
#  [0.00155615]
#  [0.00073341]
#  [0.09825411]
#  [0.06472538]
#  [0.00938456]
#  [0.16046008]
#  [0.1529696 ]
#  [0.01440386]]
# Validation Accuracy after iteration 16: 95.6043956043956%
# -------------
# [[0.16429024]
#  [0.00262007]
#  [0.00984142]
#  [0.00099057]
#  [0.04530193]
#  [0.01117368]
#  [0.02140929]
#  [0.08971235]
#  [0.04805596]
#  [0.00964607]
#  [0.00086917]
#  [0.00608738]
#  [0.02587342]
#  [0.00253116]
#  [0.00679481]
#  [0.06746726]
#  [0.11822684]
#  [0.00742381]
#  [0.00479882]
#  [0.01123483]
#  [0.06968298]
#  [0.00073878]
#  [0.00110935]
#  [0.00069289]
#  [0.09705277]
#  [0.06708462]
#  [0.01005262]
#  [0.15797964]
#  [0.14766976]
#  [0.0145688 ]]
# Validation Accuracy after iteration 17: 95.6043956043956%
# -------------
# [[0.1540108 ]
#  [0.0026382 ]
#  [0.00904613]
#  [0.00093761]
#  [0.04458441]
#  [0.00935014]
#  [0.01919783]
#  [0.08814278]
#  [0.04641887]
#  [0.00978072]
#  [0.00119378]
#  [0.00697742]
#  [0.0203079 ]
#  [0.00203934]
#  [0.00671719]
#  [0.06724727]
#  [0.11785704]
#  [0.00727882]
#  [0.00524758]
#  [0.01122675]
#  [0.06791457]
#  [0.00093264]
#  [0.00077764]
#  [0.00065217]
#  [0.09594788]
#  [0.06878482]
#  [0.00987262]
#  [0.15581141]
#  [0.14279649]
#  [0.01466674]]
# Validation Accuracy after iteration 18: 95.6043956043956%
# -------------
# [[0.14483568]
#  [0.00261863]
#  [0.00839964]
#  [0.00088634]
#  [0.04390905]
#  [0.00771753]
#  [0.01729436]
#  [0.08670134]
#  [0.04487322]
#  [0.0098984 ]
#  [0.00152908]
#  [0.00743775]
#  [0.01614041]
#  [0.00167416]
#  [0.00664312]
#  [0.06700039]
#  [0.11741005]
#  [0.00715385]
#  [0.00566378]
#  [0.01121181]
#  [0.06558527]
#  [0.00104994]
#  [0.00053452]
#  [0.00061297]
#  [0.09491692]
#  [0.07000638]
#  [0.00912872]
#  [0.15387928]
#  [0.13828639]
#  [0.01471559]]
# Validation Accuracy after iteration 19: 95.6043956043956%
# -------------
# [[0.13655494]
#  [0.00257678]
#  [0.00785638]
#  [0.00083761]
#  [0.04326897]
#  [0.00624176]
#  [0.01563228]
#  [0.08536633]
#  [0.04340912]
#  [0.01000181]
#  [0.00186049]
#  [0.00763604]
#  [0.01300805]
#  [0.00140113]
#  [0.00657195]
#  [0.06673536]
#  [0.11691051]
#  [0.00704445]
#  [0.00605133]
#  [0.01119143]
#  [0.06294748]
#  [0.00111816]
#  [0.0003583 ]
#  [0.00057599]
#  [0.09394374]
#  [0.07087497]
#  [0.00801978]
#  [0.1521291 ]
#  [0.13408946]
#  [0.01472825]]
# Validation Accuracy after iteration 20: 95.6043956043956%
# -------------
# [[0.12901719]
#  [0.00252251]
#  [0.00738785]
#  [0.00079171]
#  [0.04265899]
#  [0.00489773]
#  [0.01416215]
#  [0.08412152]
#  [0.04201812]
#  [0.0100931 ]
#  [0.0021795 ]
#  [0.00767767]
#  [0.01064088]
#  [0.00119523]
#  [0.00650324]
#  [0.06645853]
#  [0.11637715]
#  [0.00694725]
#  [0.00641349]
#  [0.01116678]
#  [0.06016327]
#  [0.00115501]
#  [0.00023193]
#  [0.0005414 ]
#  [0.09301665]
#  [0.07147961]
#  [0.00668574]
#  [0.15052162]
#  [0.13016578]
#  [0.01471411]]

# %%
# After training, evaluate the model on the test set
print('After {} Iterations'.format(iteration_count))
print('Testing Accuracy: {}%'.format(evaluate_model(test_features, test_targets, coefficients)))
# Out:
# After 20 Iterations
# Testing Accuracy: 95.65217391304348%

# %%
# After training, evaluate the model on the training set
print('After {} Iterations'.format(iteration_count))
print('Training Accuracy: {}%'.format(evaluate_model(train_features, train_targets, coefficients)))
# Out:
# After 20 Iterations
# Training Accuracy: 96.92307692307692%

# %%
# After training, evaluate the model on the validation set
print('After {} Iterations'.format(iteration_count))
print('Validation Accuracy: {}%'.format(evaluate_model(val_features, val_targets, coefficients)))
# Out:
# After 20 Iterations
# Validation Accuracy: 95.6043956043956%
